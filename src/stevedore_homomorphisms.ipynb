# %%
BSF=FreeGroup(2)

# %%
print(BSF) #x0=x0, x1=x2 in our presentation for the subgroup p_*(pi_1(unbranched cover))
# Out:
# Free Group on generators {x0, x1}

# %%
BSRelation=BSF([1,2,-1,-2,1,-2])

# %%
BS=BSF.quotient([BSRelation]) #The group BS(1,2)

# %%
a=BSF([2])*BSF([-1])

# %%
print(a) #a in the subgroup <a^p,b>, a=x2x0^-1
# Out:
# x1*x0^-1

# %%
#Finds homomorphisms from BS(1,2) to S_p
#Prints images of x0, x2, and a
#want a to have order p
def find_BS_homs(p):    
    S_p=SymmetricGroup(p)
    gen_pairs=[]
    good_homs_p=[]
    for g_1 in S_p:
        for g_2 in S_p:
            pair=[g_1,g_2]
            hom_p=BSF.hom([S_p(g) for g in pair])
            if hom_p.image(BSRelation)==S_p.identity():
                good_homs_p.append(hom_p)
                print("x0->",hom_p.image(BSF([1])),"x2->",hom_p.image(BSF([2])),"a->",hom_p.image(a),"BSRelation->",hom_p.image(BSRelation))

# %%
find_BS_homs(3)
# Out:
# x0-> () x2-> () a-> () BSRelation-> ()
# x0-> (1,3,2) x2-> (1,3,2) a-> () BSRelation-> ()
# x0-> (1,2,3) x2-> (1,2,3) a-> () BSRelation-> ()
# x0-> (2,3) x2-> (2,3) a-> () BSRelation-> ()
# x0-> (2,3) x2-> (1,3) a-> (1,2,3) BSRelation-> ()
# x0-> (2,3) x2-> (1,2) a-> (1,3,2) BSRelation-> ()
# x0-> (1,3) x2-> (2,3) a-> (1,3,2) BSRelation-> ()
# x0-> (1,3) x2-> (1,3) a-> () BSRelation-> ()
# x0-> (1,3) x2-> (1,2) a-> (1,2,3) BSRelation-> ()
# x0-> (1,2) x2-> (2,3) a-> (1,2,3) BSRelation-> ()
# x0-> (1,2) x2-> (1,3) a-> (1,3,2) BSRelation-> ()
# x0-> (1,2) x2-> (1,2) a-> () BSRelation-> ()

# %%
find_BS_homs(5)
# Out:
# x0-> () x2-> () a-> () BSRelation-> ()
# x0-> (1,5,4,3,2) x2-> (1,5,4,3,2) a-> () BSRelation-> ()
# x0-> (1,2) x2-> (1,2) a-> () BSRelation-> ()
# x0-> (1,2) x2-> (1,5) a-> (1,5,2) BSRelation-> ()
# x0-> (1,2) x2-> (1,3) a-> (1,3,2) BSRelation-> ()
# x0-> (1,2) x2-> (2,3) a-> (1,2,3) BSRelation-> ()
# x0-> (1,2) x2-> (1,4) a-> (1,4,2) BSRelation-> ()
# x0-> (1,2) x2-> (2,5) a-> (1,2,5) BSRelation-> ()
# x0-> (1,2) x2-> (2,4) a-> (1,2,4) BSRelation-> ()
# x0-> (1,4,2,5,3) x2-> (1,4,2,5,3) a-> () BSRelation-> ()
# x0-> (1,3,5,2,4) x2-> (1,3,5,2,4) a-> () BSRelation-> ()
# x0-> (2,5,4,3) x2-> (2,5,4,3) a-> () BSRelation-> ()
# x0-> (2,5,4,3) x2-> (1,2,4,5) a-> (1,3,4,2,5) BSRelation-> ()
# x0-> (2,5,4,3) x2-> (1,4,2,3) a-> (1,5,2,4,3) BSRelation-> ()
# x0-> (2,5,4,3) x2-> (1,5,3,4) a-> (1,2,3,5,4) BSRelation-> ()
# x0-> (2,5,4,3) x2-> (1,3,5,2) a-> (1,4,5,3,2) BSRelation-> ()
# x0-> (1,5,3)(2,4) x2-> (1,5,3)(2,4) a-> () BSRelation-> ()
# x0-> (1,2,5,4,3) x2-> (1,2,5,4,3) a-> () BSRelation-> ()
# x0-> (1,4)(2,3,5) x2-> (1,4)(2,3,5) a-> () BSRelation-> ()
# x0-> (1,3,4,5) x2-> (1,3,4,5) a-> () BSRelation-> ()
# x0-> (1,3,4,5) x2-> (1,4,3,2) a-> (1,3,2,5,4) BSRelation-> ()
# x0-> (1,3,4,5) x2-> (1,5,2,4) a-> (1,4,5,2,3) BSRelation-> ()
# x0-> (1,3,4,5) x2-> (1,2,5,3) a-> (1,2,4,3,5) BSRelation-> ()
# x0-> (1,3,4,5) x2-> (2,3,5,4) a-> (1,5,3,4,2) BSRelation-> ()
# x0-> (2,4)(3,5) x2-> (2,4)(3,5) a-> () BSRelation-> ()
# x0-> (2,4)(3,5) x2-> (1,3)(2,4) a-> (1,5,3) BSRelation-> ()
# x0-> (2,4)(3,5) x2-> (1,4)(3,5) a-> (1,2,4) BSRelation-> ()
# x0-> (2,4)(3,5) x2-> (1,2)(3,5) a-> (1,4,2) BSRelation-> ()
# x0-> (2,4)(3,5) x2-> (1,5)(2,4) a-> (1,3,5) BSRelation-> ()
# x0-> (1,5,2,3,4) x2-> (1,5,2,3,4) a-> () BSRelation-> ()
# x0-> (1,2,4)(3,5) x2-> (1,2,4)(3,5) a-> () BSRelation-> ()
# x0-> (1,4,5) x2-> (1,4,5) a-> () BSRelation-> ()
# x0-> (1,3,2) x2-> (1,3,2) a-> () BSRelation-> ()
# x0-> (2,3,4,5) x2-> (2,3,4,5) a-> () BSRelation-> ()
# x0-> (2,3,4,5) x2-> (1,5,3,2) a-> (1,4,3,5,2) BSRelation-> ()
# x0-> (2,3,4,5) x2-> (1,3,5,4) a-> (1,2,5,3,4) BSRelation-> ()
# x0-> (2,3,4,5) x2-> (1,2,4,3) a-> (1,5,4,2,3) BSRelation-> ()
# x0-> (2,3,4,5) x2-> (1,4,2,5) a-> (1,3,2,4,5) BSRelation-> ()
# x0-> (1,5) x2-> (1,2) a-> (1,2,5) BSRelation-> ()
# x0-> (1,5) x2-> (1,5) a-> () BSRelation-> ()
# x0-> (1,5) x2-> (1,3) a-> (1,3,5) BSRelation-> ()
# x0-> (1,5) x2-> (4,5) a-> (1,5,4) BSRelation-> ()
# x0-> (1,5) x2-> (1,4) a-> (1,4,5) BSRelation-> ()
# x0-> (1,5) x2-> (2,5) a-> (1,5,2) BSRelation-> ()
# x0-> (1,5) x2-> (3,5) a-> (1,5,3) BSRelation-> ()
# x0-> (1,2,3,4,5) x2-> (1,2,3,4,5) a-> () BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,3,4,5) a-> (1,4,5,2,3) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,4,3,2) a-> () BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,5,2,4) a-> (1,5,3,4,2) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,2,5,3) a-> (1,3,2,5,4) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (2,3,5,4) a-> (1,2,4,3,5) BSRelation-> ()
# x0-> (1,3)(2,5,4) x2-> (1,3)(2,5,4) a-> () BSRelation-> ()
# x0-> (3,4) x2-> (3,4) a-> () BSRelation-> ()
# x0-> (3,4) x2-> (1,3) a-> (1,4,3) BSRelation-> ()
# x0-> (3,4) x2-> (2,3) a-> (2,4,3) BSRelation-> ()
# x0-> (3,4) x2-> (4,5) a-> (3,4,5) BSRelation-> ()
# x0-> (3,4) x2-> (1,4) a-> (1,3,4) BSRelation-> ()
# x0-> (3,4) x2-> (3,5) a-> (3,5,4) BSRelation-> ()
# x0-> (3,4) x2-> (2,4) a-> (2,3,4) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,5,4,2) a-> () BSRelation-> ()
# x0-> (1,5,4,2) x2-> (2,4,3,5) a-> (1,2,5,4,3) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,2,3,4) a-> (1,4,2,3,5) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,3,2,5) a-> (1,3,4,5,2) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,4,5,3) a-> (1,5,3,2,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(3,4) a-> () BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,5)(3,4) a-> (1,5,2) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(4,5) a-> (3,4,5) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(3,5) a-> (3,5,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,5)(3,4) a-> (1,2,5) BSRelation-> ()
# x0-> (1,4)(2,5,3) x2-> (1,4)(2,5,3) a-> () BSRelation-> ()
# x0-> (1,3)(2,4,5) x2-> (1,3)(2,4,5) a-> () BSRelation-> ()
# x0-> (2,5,4) x2-> (2,5,4) a-> () BSRelation-> ()
# x0-> (1,5,3,2,4) x2-> (1,5,3,2,4) a-> () BSRelation-> ()
# x0-> (1,2,5,4) x2-> (1,2,5,4) a-> () BSRelation-> ()
# x0-> (1,2,5,4) x2-> (2,4,5,3) a-> (1,4,2,5,3) BSRelation-> ()
# x0-> (1,2,5,4) x2-> (1,5,2,3) a-> (1,2,3,4,5) BSRelation-> ()
# x0-> (1,2,5,4) x2-> (1,4,3,5) a-> (1,5,4,3,2) BSRelation-> ()
# x0-> (1,2,5,4) x2-> (1,3,4,2) a-> (1,3,5,2,4) BSRelation-> ()
# x0-> (1,4,5,2,3) x2-> (1,4,5,2,3) a-> () BSRelation-> ()
# x0-> (1,3,5) x2-> (1,3,5) a-> () BSRelation-> ()
# x0-> (2,4,5,3) x2-> (1,2,5,4) a-> (1,3,5,2,4) BSRelation-> ()
# x0-> (2,4,5,3) x2-> (2,4,5,3) a-> () BSRelation-> ()
# x0-> (2,4,5,3) x2-> (1,5,2,3) a-> (1,4,2,5,3) BSRelation-> ()
# x0-> (2,4,5,3) x2-> (1,4,3,5) a-> (1,2,3,4,5) BSRelation-> ()
# x0-> (2,4,5,3) x2-> (1,3,4,2) a-> (1,5,4,3,2) BSRelation-> ()
# x0-> (1,5,2,3) x2-> (1,2,5,4) a-> (1,5,4,3,2) BSRelation-> ()
# x0-> (1,5,2,3) x2-> (2,4,5,3) a-> (1,3,5,2,4) BSRelation-> ()
# x0-> (1,5,2,3) x2-> (1,5,2,3) a-> () BSRelation-> ()
# x0-> (1,5,2,3) x2-> (1,4,3,5) a-> (1,4,2,5,3) BSRelation-> ()
# x0-> (1,5,2,3) x2-> (1,3,4,2) a-> (1,2,3,4,5) BSRelation-> ()
# x0-> (1,2,4,5,3) x2-> (1,2,4,5,3) a-> () BSRelation-> ()
# x0-> (1,4,3,5) x2-> (1,2,5,4) a-> (1,2,3,4,5) BSRelation-> ()
# x0-> (1,4,3,5) x2-> (2,4,5,3) a-> (1,5,4,3,2) BSRelation-> ()
# x0-> (1,4,3,5) x2-> (1,5,2,3) a-> (1,3,5,2,4) BSRelation-> ()
# x0-> (1,4,3,5) x2-> (1,4,3,5) a-> () BSRelation-> ()
# x0-> (1,4,3,5) x2-> (1,3,4,2) a-> (1,4,2,5,3) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,2,5,4) a-> (1,4,2,5,3) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (2,4,5,3) a-> (1,2,3,4,5) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,5,2,3) a-> (1,5,4,3,2) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,4,3,5) a-> (1,3,5,2,4) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,3,4,2) a-> () BSRelation-> ()
# x0-> (2,3,5) x2-> (2,3,5) a-> () BSRelation-> ()
# x0-> (1,5)(3,4) x2-> (1,2)(3,4) a-> (1,2,5) BSRelation-> ()
# x0-> (1,5)(3,4) x2-> (1,5)(3,4) a-> () BSRelation-> ()
# x0-> (1,5)(3,4) x2-> (1,5)(2,3) a-> (2,4,3) BSRelation-> ()
# x0-> (1,5)(3,4) x2-> (2,5)(3,4) a-> (1,5,2) BSRelation-> ()
# x0-> (1,5)(3,4) x2-> (1,5)(2,4) a-> (2,3,4) BSRelation-> ()
# x0-> (1,2,3,5) x2-> (1,2,3,5) a-> () BSRelation-> ()
# x0-> (1,2,3,5) x2-> (2,5,3,4) a-> (1,5,2,3,4) BSRelation-> ()
# x0-> (1,2,3,5) x2-> (1,5,4,3) a-> (1,3,5,4,2) BSRelation-> ()
# x0-> (1,2,3,5) x2-> (1,4,5,2) a-> (1,4,3,2,5) BSRelation-> ()
# x0-> (1,2,3,5) x2-> (1,3,2,4) a-> (1,2,4,5,3) BSRelation-> ()
# x0-> (1,4,2) x2-> (1,4,2) a-> () BSRelation-> ()
# x0-> (1,3,2,5,4) x2-> (1,3,2,5,4) a-> () BSRelation-> ()
# x0-> (3,5,4) x2-> (3,5,4) a-> () BSRelation-> ()
# x0-> (1,5,3,4,2) x2-> (1,5,3,4,2) a-> () BSRelation-> ()
# x0-> (1,2)(3,5,4) x2-> (1,2)(3,5,4) a-> () BSRelation-> ()
# x0-> (1,4)(2,5) x2-> (1,4)(2,5) a-> () BSRelation-> ()
# x0-> (1,4)(2,5) x2-> (1,3)(2,5) a-> (1,3,4) BSRelation-> ()
# x0-> (1,4)(2,5) x2-> (1,4)(3,5) a-> (2,5,3) BSRelation-> ()
# x0-> (1,4)(2,5) x2-> (2,5)(3,4) a-> (1,4,3) BSRelation-> ()
# x0-> (1,4)(2,5) x2-> (1,4)(2,3) a-> (2,3,5) BSRelation-> ()
# x0-> (1,3,2,4,5) x2-> (1,3,2,4,5) a-> () BSRelation-> ()
# x0-> (2,5,3,4) x2-> (1,2,3,5) a-> (1,4,3,2,5) BSRelation-> ()
# x0-> (2,5,3,4) x2-> (2,5,3,4) a-> () BSRelation-> ()
# x0-> (2,5,3,4) x2-> (1,5,4,3) a-> (1,2,4,5,3) BSRelation-> ()
# x0-> (2,5,3,4) x2-> (1,4,5,2) a-> (1,3,5,4,2) BSRelation-> ()
# x0-> (2,5,3,4) x2-> (1,3,2,4) a-> (1,5,2,3,4) BSRelation-> ()
# x0-> (1,5,2,4) x2-> (1,3,4,5) a-> (1,3,2,5,4) BSRelation-> ()
# x0-> (1,5,2,4) x2-> (1,4,3,2) a-> (1,2,4,3,5) BSRelation-> ()
# x0-> (1,5,2,4) x2-> (1,5,2,4) a-> () BSRelation-> ()
# x0-> (1,5,2,4) x2-> (1,2,5,3) a-> (1,5,3,4,2) BSRelation-> ()
# x0-> (1,5,2,4) x2-> (2,3,5,4) a-> (1,4,5,2,3) BSRelation-> ()
# x0-> (1,2,5,3,4) x2-> (1,2,5,3,4) a-> () BSRelation-> ()
# x0-> (1,4,5)(2,3) x2-> (1,4,5)(2,3) a-> () BSRelation-> ()
# x0-> (1,3) x2-> (1,2) a-> (1,2,3) BSRelation-> ()
# x0-> (1,3) x2-> (1,5) a-> (1,5,3) BSRelation-> ()
# x0-> (1,3) x2-> (3,4) a-> (1,3,4) BSRelation-> ()
# x0-> (1,3) x2-> (1,3) a-> () BSRelation-> ()
# x0-> (1,3) x2-> (2,3) a-> (1,3,2) BSRelation-> ()
# x0-> (1,3) x2-> (1,4) a-> (1,4,3) BSRelation-> ()
# x0-> (1,3) x2-> (3,5) a-> (1,3,5) BSRelation-> ()
# x0-> (2,4,5) x2-> (2,4,5) a-> () BSRelation-> ()
# x0-> (1,5)(2,3) x2-> (1,5)(3,4) a-> (2,3,4) BSRelation-> ()
# x0-> (1,5)(2,3) x2-> (1,5)(2,3) a-> () BSRelation-> ()
# x0-> (1,5)(2,3) x2-> (1,5)(2,4) a-> (2,4,3) BSRelation-> ()
# x0-> (1,5)(2,3) x2-> (1,4)(2,3) a-> (1,4,5) BSRelation-> ()
# x0-> (1,5)(2,3) x2-> (2,3)(4,5) a-> (1,5,4) BSRelation-> ()
# x0-> (1,2,4,5) x2-> (2,5,4,3) a-> (1,5,2,4,3) BSRelation-> ()
# x0-> (1,2,4,5) x2-> (1,2,4,5) a-> () BSRelation-> ()
# x0-> (1,2,4,5) x2-> (1,4,2,3) a-> (1,2,3,5,4) BSRelation-> ()
# x0-> (1,2,4,5) x2-> (1,5,3,4) a-> (1,4,5,3,2) BSRelation-> ()
# x0-> (1,2,4,5) x2-> (1,3,5,2) a-> (1,3,4,2,5) BSRelation-> ()
# x0-> (1,4,3) x2-> (1,4,3) a-> () BSRelation-> ()
# x0-> (1,3,5,4,2) x2-> (1,3,5,4,2) a-> () BSRelation-> ()
# x0-> (2,3) x2-> (1,2) a-> (1,3,2) BSRelation-> ()
# x0-> (2,3) x2-> (3,4) a-> (2,3,4) BSRelation-> ()
# x0-> (2,3) x2-> (1,3) a-> (1,2,3) BSRelation-> ()
# x0-> (2,3) x2-> (2,3) a-> () BSRelation-> ()
# x0-> (2,3) x2-> (2,5) a-> (2,5,3) BSRelation-> ()
# x0-> (2,3) x2-> (3,5) a-> (2,3,5) BSRelation-> ()
# x0-> (2,3) x2-> (2,4) a-> (2,4,3) BSRelation-> ()
# x0-> (1,5,4,3) x2-> (1,2,3,5) a-> (1,2,4,5,3) BSRelation-> ()
# x0-> (1,5,4,3) x2-> (2,5,3,4) a-> (1,3,5,4,2) BSRelation-> ()
# x0-> (1,5,4,3) x2-> (1,5,4,3) a-> () BSRelation-> ()
# x0-> (1,5,4,3) x2-> (1,4,5,2) a-> (1,5,2,3,4) BSRelation-> ()
# x0-> (1,5,4,3) x2-> (1,3,2,4) a-> (1,4,3,2,5) BSRelation-> ()
# x0-> (1,2,3) x2-> (1,2,3) a-> () BSRelation-> ()
# x0-> (1,4,2)(3,5) x2-> (1,4,2)(3,5) a-> () BSRelation-> ()
# x0-> (1,3,4)(2,5) x2-> (1,3,4)(2,5) a-> () BSRelation-> ()
# x0-> (4,5) x2-> (1,5) a-> (1,4,5) BSRelation-> ()
# x0-> (4,5) x2-> (3,4) a-> (3,5,4) BSRelation-> ()
# x0-> (4,5) x2-> (4,5) a-> () BSRelation-> ()
# x0-> (4,5) x2-> (1,4) a-> (1,5,4) BSRelation-> ()
# x0-> (4,5) x2-> (2,5) a-> (2,4,5) BSRelation-> ()
# x0-> (4,5) x2-> (3,5) a-> (3,4,5) BSRelation-> ()
# x0-> (4,5) x2-> (2,4) a-> (2,5,4) BSRelation-> ()
# x0-> (1,5,3,2) x2-> (2,3,4,5) a-> (1,2,5,3,4) BSRelation-> ()
# x0-> (1,5,3,2) x2-> (1,5,3,2) a-> () BSRelation-> ()
# x0-> (1,5,3,2) x2-> (1,3,5,4) a-> (1,5,4,2,3) BSRelation-> ()
# x0-> (1,5,3,2) x2-> (1,2,4,3) a-> (1,3,2,4,5) BSRelation-> ()
# x0-> (1,5,3,2) x2-> (1,4,2,5) a-> (1,4,3,5,2) BSRelation-> ()
# x0-> (1,2)(4,5) x2-> (1,2)(3,4) a-> (3,5,4) BSRelation-> ()
# x0-> (1,2)(4,5) x2-> (1,2)(4,5) a-> () BSRelation-> ()
# x0-> (1,2)(4,5) x2-> (1,2)(3,5) a-> (3,4,5) BSRelation-> ()
# x0-> (1,2)(4,5) x2-> (1,3)(4,5) a-> (1,3,2) BSRelation-> ()
# x0-> (1,2)(4,5) x2-> (2,3)(4,5) a-> (1,2,3) BSRelation-> ()
# x0-> (1,4,3)(2,5) x2-> (1,4,3)(2,5) a-> () BSRelation-> ()
# x0-> (1,3,5)(2,4) x2-> (1,3,5)(2,4) a-> () BSRelation-> ()
# x0-> (2,5,3) x2-> (2,5,3) a-> () BSRelation-> ()
# x0-> (1,5,2,4,3) x2-> (1,5,2,4,3) a-> () BSRelation-> ()
# x0-> (1,2,5,3) x2-> (1,3,4,5) a-> (1,5,3,4,2) BSRelation-> ()
# x0-> (1,2,5,3) x2-> (1,4,3,2) a-> (1,4,5,2,3) BSRelation-> ()
# x0-> (1,2,5,3) x2-> (1,5,2,4) a-> (1,2,4,3,5) BSRelation-> ()
# x0-> (1,2,5,3) x2-> (1,2,5,3) a-> () BSRelation-> ()
# x0-> (1,2,5,3) x2-> (2,3,5,4) a-> (1,3,2,5,4) BSRelation-> ()
# x0-> (1,4,2,3,5) x2-> (1,4,2,3,5) a-> () BSRelation-> ()
# x0-> (1,3,4) x2-> (1,3,4) a-> () BSRelation-> ()
# x0-> (2,4,3,5) x2-> (1,5,4,2) a-> (1,3,4,5,2) BSRelation-> ()
# x0-> (2,4,3,5) x2-> (2,4,3,5) a-> () BSRelation-> ()
# x0-> (2,4,3,5) x2-> (1,2,3,4) a-> (1,5,3,2,4) BSRelation-> ()
# x0-> (2,4,3,5) x2-> (1,3,2,5) a-> (1,4,2,3,5) BSRelation-> ()
# x0-> (2,4,3,5) x2-> (1,4,5,3) a-> (1,2,5,4,3) BSRelation-> ()
# x0-> (1,5)(2,3,4) x2-> (1,5)(2,3,4) a-> () BSRelation-> ()
# x0-> (1,2,4,3,5) x2-> (1,2,4,3,5) a-> () BSRelation-> ()
# x0-> (1,4) x2-> (1,2) a-> (1,2,4) BSRelation-> ()
# x0-> (1,4) x2-> (1,5) a-> (1,5,4) BSRelation-> ()
# x0-> (1,4) x2-> (3,4) a-> (1,4,3) BSRelation-> ()
# x0-> (1,4) x2-> (1,3) a-> (1,3,4) BSRelation-> ()
# x0-> (1,4) x2-> (4,5) a-> (1,4,5) BSRelation-> ()
# x0-> (1,4) x2-> (1,4) a-> () BSRelation-> ()
# x0-> (1,4) x2-> (2,4) a-> (1,4,2) BSRelation-> ()
# x0-> (1,3,2)(4,5) x2-> (1,3,2)(4,5) a-> () BSRelation-> ()
# x0-> (2,3,4) x2-> (2,3,4) a-> () BSRelation-> ()
# x0-> (1,5,4) x2-> (1,5,4) a-> () BSRelation-> ()
# x0-> (1,2,3,4) x2-> (1,5,4,2) a-> (1,5,3,2,4) BSRelation-> ()
# x0-> (1,2,3,4) x2-> (2,4,3,5) a-> (1,4,2,3,5) BSRelation-> ()
# x0-> (1,2,3,4) x2-> (1,2,3,4) a-> () BSRelation-> ()
# x0-> (1,2,3,4) x2-> (1,3,2,5) a-> (1,2,5,4,3) BSRelation-> ()
# x0-> (1,2,3,4) x2-> (1,4,5,3) a-> (1,3,4,5,2) BSRelation-> ()
# x0-> (1,4,5,3,2) x2-> (1,4,5,3,2) a-> () BSRelation-> ()
# x0-> (1,3)(2,5) x2-> (1,4)(2,5) a-> (1,4,3) BSRelation-> ()
# x0-> (1,3)(2,5) x2-> (1,3)(2,5) a-> () BSRelation-> ()
# x0-> (1,3)(2,5) x2-> (1,3)(2,4) a-> (2,4,5) BSRelation-> ()
# x0-> (1,3)(2,5) x2-> (2,5)(3,4) a-> (1,3,4) BSRelation-> ()
# x0-> (1,3)(2,5) x2-> (1,3)(4,5) a-> (2,5,4) BSRelation-> ()
# x0-> (3,4,5) x2-> (3,4,5) a-> () BSRelation-> ()
# x0-> (1,5,2) x2-> (1,5,2) a-> () BSRelation-> ()
# x0-> (1,2)(3,4,5) x2-> (1,2)(3,4,5) a-> () BSRelation-> ()
# x0-> (1,4,3,2,5) x2-> (1,4,3,2,5) a-> () BSRelation-> ()
# x0-> (1,3)(2,4) x2-> (2,4)(3,5) a-> (1,3,5) BSRelation-> ()
# x0-> (1,3)(2,4) x2-> (1,3)(2,5) a-> (2,5,4) BSRelation-> ()
# x0-> (1,3)(2,4) x2-> (1,3)(2,4) a-> () BSRelation-> ()
# x0-> (1,3)(2,4) x2-> (1,5)(2,4) a-> (1,5,3) BSRelation-> ()
# x0-> (1,3)(2,4) x2-> (1,3)(4,5) a-> (2,4,5) BSRelation-> ()
# x0-> (2,5) x2-> (1,2) a-> (1,5,2) BSRelation-> ()
# x0-> (2,5) x2-> (1,5) a-> (1,2,5) BSRelation-> ()
# x0-> (2,5) x2-> (2,3) a-> (2,3,5) BSRelation-> ()
# x0-> (2,5) x2-> (4,5) a-> (2,5,4) BSRelation-> ()
# x0-> (2,5) x2-> (2,5) a-> () BSRelation-> ()
# x0-> (2,5) x2-> (3,5) a-> (2,5,3) BSRelation-> ()
# x0-> (2,5) x2-> (2,4) a-> (2,4,5) BSRelation-> ()
# x0-> (1,5)(2,4,3) x2-> (1,5)(2,4,3) a-> () BSRelation-> ()
# x0-> (1,2,5) x2-> (1,2,5) a-> () BSRelation-> ()
# x0-> (1,4,2,3) x2-> (2,5,4,3) a-> (1,3,4,2,5) BSRelation-> ()
# x0-> (1,4,2,3) x2-> (1,2,4,5) a-> (1,4,5,3,2) BSRelation-> ()
# x0-> (1,4,2,3) x2-> (1,4,2,3) a-> () BSRelation-> ()
# x0-> (1,4,2,3) x2-> (1,5,3,4) a-> (1,5,2,4,3) BSRelation-> ()
# x0-> (1,4,2,3) x2-> (1,3,5,2) a-> (1,2,3,5,4) BSRelation-> ()
# x0-> (1,3,5,4) x2-> (2,3,4,5) a-> (1,4,3,5,2) BSRelation-> ()
# x0-> (1,3,5,4) x2-> (1,5,3,2) a-> (1,3,2,4,5) BSRelation-> ()
# x0-> (1,3,5,4) x2-> (1,3,5,4) a-> () BSRelation-> ()
# x0-> (1,3,5,4) x2-> (1,2,4,3) a-> (1,2,5,3,4) BSRelation-> ()
# x0-> (1,3,5,4) x2-> (1,4,2,5) a-> (1,5,4,2,3) BSRelation-> ()
# x0-> (2,4,3) x2-> (2,4,3) a-> () BSRelation-> ()
# x0-> (1,5,4,2,3) x2-> (1,5,4,2,3) a-> () BSRelation-> ()
# x0-> (1,2,4,3) x2-> (2,3,4,5) a-> (1,3,2,4,5) BSRelation-> ()
# x0-> (1,2,4,3) x2-> (1,5,3,2) a-> (1,5,4,2,3) BSRelation-> ()
# x0-> (1,2,4,3) x2-> (1,3,5,4) a-> (1,4,3,5,2) BSRelation-> ()
# x0-> (1,2,4,3) x2-> (1,2,4,3) a-> () BSRelation-> ()
# x0-> (1,2,4,3) x2-> (1,4,2,5) a-> (1,2,5,3,4) BSRelation-> ()
# x0-> (1,4)(3,5) x2-> (2,4)(3,5) a-> (1,4,2) BSRelation-> ()
# x0-> (1,4)(3,5) x2-> (1,4)(2,5) a-> (2,3,5) BSRelation-> ()
# x0-> (1,4)(3,5) x2-> (1,4)(3,5) a-> () BSRelation-> ()
# x0-> (1,4)(3,5) x2-> (1,2)(3,5) a-> (1,2,4) BSRelation-> ()
# x0-> (1,4)(3,5) x2-> (1,4)(2,3) a-> (2,5,3) BSRelation-> ()
# x0-> (1,3,4,5,2) x2-> (1,3,4,5,2) a-> () BSRelation-> ()
# x0-> (2,3,5,4) x2-> (1,3,4,5) a-> (1,2,4,3,5) BSRelation-> ()
# x0-> (2,3,5,4) x2-> (1,4,3,2) a-> (1,5,3,4,2) BSRelation-> ()
# x0-> (2,3,5,4) x2-> (1,5,2,4) a-> (1,3,2,5,4) BSRelation-> ()
# x0-> (2,3,5,4) x2-> (1,2,5,3) a-> (1,4,5,2,3) BSRelation-> ()
# x0-> (2,3,5,4) x2-> (2,3,5,4) a-> () BSRelation-> ()
# x0-> (1,5,3,4) x2-> (2,5,4,3) a-> (1,4,5,3,2) BSRelation-> ()
# x0-> (1,5,3,4) x2-> (1,2,4,5) a-> (1,2,3,5,4) BSRelation-> ()
# x0-> (1,5,3,4) x2-> (1,4,2,3) a-> (1,3,4,2,5) BSRelation-> ()
# x0-> (1,5,3,4) x2-> (1,5,3,4) a-> () BSRelation-> ()
# x0-> (1,5,3,4) x2-> (1,3,5,2) a-> (1,5,2,4,3) BSRelation-> ()
# x0-> (1,2,3,5,4) x2-> (1,2,3,5,4) a-> () BSRelation-> ()
# x0-> (1,4,5,2) x2-> (1,2,3,5) a-> (1,5,2,3,4) BSRelation-> ()
# x0-> (1,4,5,2) x2-> (2,5,3,4) a-> (1,2,4,5,3) BSRelation-> ()
# x0-> (1,4,5,2) x2-> (1,5,4,3) a-> (1,4,3,2,5) BSRelation-> ()
# x0-> (1,4,5,2) x2-> (1,4,5,2) a-> () BSRelation-> ()
# x0-> (1,4,5,2) x2-> (1,3,2,4) a-> (1,3,5,4,2) BSRelation-> ()
# x0-> (1,3,2,5) x2-> (1,5,4,2) a-> (1,2,5,4,3) BSRelation-> ()
# x0-> (1,3,2,5) x2-> (2,4,3,5) a-> (1,5,3,2,4) BSRelation-> ()
# x0-> (1,3,2,5) x2-> (1,2,3,4) a-> (1,3,4,5,2) BSRelation-> ()
# x0-> (1,3,2,5) x2-> (1,3,2,5) a-> () BSRelation-> ()
# x0-> (1,3,2,5) x2-> (1,4,5,3) a-> (1,4,2,3,5) BSRelation-> ()
# x0-> (3,5) x2-> (1,5) a-> (1,3,5) BSRelation-> ()
# x0-> (3,5) x2-> (3,4) a-> (3,4,5) BSRelation-> ()
# x0-> (3,5) x2-> (1,3) a-> (1,5,3) BSRelation-> ()
# x0-> (3,5) x2-> (2,3) a-> (2,5,3) BSRelation-> ()
# x0-> (3,5) x2-> (4,5) a-> (3,5,4) BSRelation-> ()
# x0-> (3,5) x2-> (2,5) a-> (2,3,5) BSRelation-> ()
# x0-> (3,5) x2-> (3,5) a-> () BSRelation-> ()
# x0-> (1,5,2)(3,4) x2-> (1,5,2)(3,4) a-> () BSRelation-> ()
# x0-> (1,2)(3,5) x2-> (2,4)(3,5) a-> (1,2,4) BSRelation-> ()
# x0-> (1,2)(3,5) x2-> (1,2)(3,4) a-> (3,4,5) BSRelation-> ()
# x0-> (1,2)(3,5) x2-> (1,2)(4,5) a-> (3,5,4) BSRelation-> ()
# x0-> (1,2)(3,5) x2-> (1,4)(3,5) a-> (1,4,2) BSRelation-> ()
# x0-> (1,2)(3,5) x2-> (1,2)(3,5) a-> () BSRelation-> ()
# x0-> (1,4,2,5) x2-> (2,3,4,5) a-> (1,5,4,2,3) BSRelation-> ()
# x0-> (1,4,2,5) x2-> (1,5,3,2) a-> (1,2,5,3,4) BSRelation-> ()
# x0-> (1,4,2,5) x2-> (1,3,5,4) a-> (1,3,2,4,5) BSRelation-> ()
# x0-> (1,4,2,5) x2-> (1,2,4,3) a-> (1,4,3,5,2) BSRelation-> ()
# x0-> (1,4,2,5) x2-> (1,4,2,5) a-> () BSRelation-> ()
# x0-> (1,3,2,4) x2-> (1,2,3,5) a-> (1,3,5,4,2) BSRelation-> ()
# x0-> (1,3,2,4) x2-> (2,5,3,4) a-> (1,4,3,2,5) BSRelation-> ()
# x0-> (1,3,2,4) x2-> (1,5,4,3) a-> (1,5,2,3,4) BSRelation-> ()
# x0-> (1,3,2,4) x2-> (1,4,5,2) a-> (1,2,4,5,3) BSRelation-> ()
# x0-> (1,3,2,4) x2-> (1,3,2,4) a-> () BSRelation-> ()
# x0-> (2,5)(3,4) x2-> (1,2)(3,4) a-> (1,5,2) BSRelation-> ()
# x0-> (2,5)(3,4) x2-> (1,5)(3,4) a-> (1,2,5) BSRelation-> ()
# x0-> (2,5)(3,4) x2-> (1,4)(2,5) a-> (1,3,4) BSRelation-> ()
# x0-> (2,5)(3,4) x2-> (1,3)(2,5) a-> (1,4,3) BSRelation-> ()
# x0-> (2,5)(3,4) x2-> (2,5)(3,4) a-> () BSRelation-> ()
# x0-> (1,5)(2,4) x2-> (2,4)(3,5) a-> (1,5,3) BSRelation-> ()
# x0-> (1,5)(2,4) x2-> (1,5)(3,4) a-> (2,4,3) BSRelation-> ()
# x0-> (1,5)(2,4) x2-> (1,5)(2,3) a-> (2,3,4) BSRelation-> ()
# x0-> (1,5)(2,4) x2-> (1,3)(2,4) a-> (1,3,5) BSRelation-> ()
# x0-> (1,5)(2,4) x2-> (1,5)(2,4) a-> () BSRelation-> ()
# x0-> (1,2,5)(3,4) x2-> (1,2,5)(3,4) a-> () BSRelation-> ()
# x0-> (1,4)(2,3) x2-> (1,4)(2,5) a-> (2,5,3) BSRelation-> ()
# x0-> (1,4)(2,3) x2-> (1,5)(2,3) a-> (1,5,4) BSRelation-> ()
# x0-> (1,4)(2,3) x2-> (1,4)(3,5) a-> (2,3,5) BSRelation-> ()
# x0-> (1,4)(2,3) x2-> (1,4)(2,3) a-> () BSRelation-> ()
# x0-> (1,4)(2,3) x2-> (2,3)(4,5) a-> (1,4,5) BSRelation-> ()
# x0-> (1,3)(4,5) x2-> (1,2)(4,5) a-> (1,2,3) BSRelation-> ()
# x0-> (1,3)(4,5) x2-> (1,3)(2,5) a-> (2,4,5) BSRelation-> ()
# x0-> (1,3)(4,5) x2-> (1,3)(2,4) a-> (2,5,4) BSRelation-> ()
# x0-> (1,3)(4,5) x2-> (1,3)(4,5) a-> () BSRelation-> ()
# x0-> (1,3)(4,5) x2-> (2,3)(4,5) a-> (1,3,2) BSRelation-> ()
# x0-> (2,4) x2-> (1,2) a-> (1,4,2) BSRelation-> ()
# x0-> (2,4) x2-> (3,4) a-> (2,4,3) BSRelation-> ()
# x0-> (2,4) x2-> (2,3) a-> (2,3,4) BSRelation-> ()
# x0-> (2,4) x2-> (4,5) a-> (2,4,5) BSRelation-> ()
# x0-> (2,4) x2-> (1,4) a-> (1,2,4) BSRelation-> ()
# x0-> (2,4) x2-> (2,5) a-> (2,5,4) BSRelation-> ()
# x0-> (2,4) x2-> (2,4) a-> () BSRelation-> ()
# x0-> (1,5,4)(2,3) x2-> (1,5,4)(2,3) a-> () BSRelation-> ()
# x0-> (1,2,4) x2-> (1,2,4) a-> () BSRelation-> ()
# x0-> (1,4,5,3) x2-> (1,5,4,2) a-> (1,4,2,3,5) BSRelation-> ()
# x0-> (1,4,5,3) x2-> (2,4,3,5) a-> (1,3,4,5,2) BSRelation-> ()
# x0-> (1,4,5,3) x2-> (1,2,3,4) a-> (1,2,5,4,3) BSRelation-> ()
# x0-> (1,4,5,3) x2-> (1,3,2,5) a-> (1,5,3,2,4) BSRelation-> ()
# x0-> (1,4,5,3) x2-> (1,4,5,3) a-> () BSRelation-> ()
# x0-> (1,3,5,2) x2-> (2,5,4,3) a-> (1,2,3,5,4) BSRelation-> ()
# x0-> (1,3,5,2) x2-> (1,2,4,5) a-> (1,5,2,4,3) BSRelation-> ()
# x0-> (1,3,5,2) x2-> (1,4,2,3) a-> (1,4,5,3,2) BSRelation-> ()
# x0-> (1,3,5,2) x2-> (1,5,3,4) a-> (1,3,4,2,5) BSRelation-> ()
# x0-> (1,3,5,2) x2-> (1,3,5,2) a-> () BSRelation-> ()
# x0-> (2,3)(4,5) x2-> (1,5)(2,3) a-> (1,4,5) BSRelation-> ()
# x0-> (2,3)(4,5) x2-> (1,2)(4,5) a-> (1,3,2) BSRelation-> ()
# x0-> (2,3)(4,5) x2-> (1,4)(2,3) a-> (1,5,4) BSRelation-> ()
# x0-> (2,3)(4,5) x2-> (1,3)(4,5) a-> (1,2,3) BSRelation-> ()
# x0-> (2,3)(4,5) x2-> (2,3)(4,5) a-> () BSRelation-> ()
# x0-> (1,5,3) x2-> (1,5,3) a-> () BSRelation-> ()
# x0-> (1,2,3)(4,5) x2-> (1,2,3)(4,5) a-> () BSRelation-> ()
# x0-> (1,4,3,5,2) x2-> (1,4,3,5,2) a-> () BSRelation-> ()
# x0-> (1,3,4,2,5) x2-> (1,3,4,2,5) a-> () BSRelation-> ()

# %%
#find_BS_homs(7) #reaches memory limit
# Out:
# x0-> () x2-> () a-> () BSRelation-> ()
# x0-> (1,7,6,5,4,3,2) x2-> (1,7,6,5,4,3,2) a-> () BSRelation-> ()
# x0-> (1,2) x2-> (1,2) a-> () BSRelation-> ()
# x0-> (1,2) x2-> (1,7) a-> (1,7,2) BSRelation-> ()
# x0-> (1,2) x2-> (1,3) a-> (1,3,2) BSRelation-> ()
# x0-> (1,2) x2-> (2,3) a-> (1,2,3) BSRelation-> ()
# x0-> (1,2) x2-> (1,4) a-> (1,4,2) BSRelation-> ()
# x0-> (1,2) x2-> (2,4) a-> (1,2,4) BSRelation-> ()
# x0-> (1,2) x2-> (1,5) a-> (1,5,2) BSRelation-> ()
# x0-> (1,2) x2-> (2,5) a-> (1,2,5) BSRelation-> ()
# x0-> (1,2) x2-> (1,6) a-> (1,6,2) BSRelation-> ()
# x0-> (1,2) x2-> (2,7) a-> (1,2,7) BSRelation-> ()
# x0-> (1,2) x2-> (2,6) a-> (1,2,6) BSRelation-> ()
# x0-> (1,6,4,2,7,5,3) x2-> (1,6,4,2,7,5,3) a-> () BSRelation-> ()
# x0-> (1,5,2,6,3,7,4) x2-> (1,5,2,6,3,7,4) a-> () BSRelation-> ()
# x0-> (1,4,7,3,6,2,5) x2-> (1,4,7,3,6,2,5) a-> () BSRelation-> ()
# x0-> (1,3,5,7,2,4,6) x2-> (1,3,5,7,2,4,6) a-> () BSRelation-> ()
# x0-> (2,7,6,5,4,3) x2-> (2,7,6,5,4,3) a-> () BSRelation-> ()
# x0-> (2,7,6,5,4,3) x2-> (2,5,6,3,4,7) a-> (2,6,4)(3,5,7) BSRelation-> ()
# x0-> (2,7,6,5,4,3) x2-> (2,3,6,7,4,5) a-> (2,4,6)(3,7,5) BSRelation-> ()
# x0-> (1,7,5,3)(2,6,4) x2-> (1,7,5,3)(2,6,4) a-> () BSRelation-> ()
# x0-> (1,2,7,6,5,4,3) x2-> (1,2,7,6,5,4,3) a-> () BSRelation-> ()
# x0-> (1,6,3,7,4)(2,5) x2-> (1,6,3,7,4)(2,5) a-> () BSRelation-> ()
# x0-> (1,5)(2,4,7,3,6) x2-> (1,5)(2,4,7,3,6) a-> () BSRelation-> ()
# x0-> (1,4,6)(2,3,5,7) x2-> (1,4,6)(2,3,5,7) a-> () BSRelation-> ()
# x0-> (1,3,4,5,6,7) x2-> (1,3,4,5,6,7) a-> () BSRelation-> ()
# x0-> (1,3,4,5,6,7) x2-> (1,5,4,7,6,3) a-> (1,4,6)(3,7,5) BSRelation-> ()
# x0-> (1,3,4,5,6,7) x2-> (1,7,4,3,6,5) a-> (1,6,4)(3,5,7) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (2,6,4)(3,7,5) a-> () BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,6,7)(3,5,4) a-> (1,2,4,5,6,3,7) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,3,6)(2,4,7) a-> (1,5,7,4,3,2,6) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,7,4)(2,5,6) a-> (1,3,5,2,7,6,4) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,5,2)(3,4,6) a-> (1,7,3,6,5,4,2) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,3,4)(2,7,6) a-> (1,5,7,2,3,6,4) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,2,5)(3,6,7) a-> (1,4,6,3,2,7,5) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,4,3)(2,5,7) a-> (1,6,2,7,4,5,3) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,2,3)(5,7,6) a-> (1,4,6,7,2,5,3) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,4,7)(2,3,5) a-> (1,6,2,5,4,3,7) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,6,3)(4,5,7) a-> (1,2,4,7,6,5,3) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,5,4)(2,3,6) a-> (1,7,3,2,5,6,4) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,4,5)(2,7,3) a-> (1,6,2,3,4,7,5) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,5,6)(2,4,3) a-> (1,7,3,4,5,2,6) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,3,2)(4,6,7) a-> (1,5,7,6,3,4,2) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,7,2)(4,6,5) a-> (1,3,5,6,7,4,2) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,7,6)(2,4,5) a-> (1,3,5,4,7,2,6) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,6,5)(3,4,7) a-> (1,2,4,3,6,7,5) BSRelation-> ()
# x0-> (2,6,4)(3,7,5) x2-> (1,2,7)(3,5,6) a-> (1,4,6,5,2,3,7) BSRelation-> ()
# x0-> (1,7,4)(2,5)(3,6) x2-> (1,7,4)(2,5)(3,6) a-> () BSRelation-> ()
# x0-> (1,2,6,4)(3,7,5) x2-> (1,2,6,4)(3,7,5) a-> () BSRelation-> ()
# x0-> (1,6,2,4,7,3,5) x2-> (1,6,2,4,7,3,5) a-> () BSRelation-> ()
# x0-> (1,5,7,2,3,4,6) x2-> (1,5,7,2,3,4,6) a-> () BSRelation-> ()
# x0-> (1,4,5,6,7) x2-> (1,4,5,6,7) a-> () BSRelation-> ()
# x0-> (1,3,2) x2-> (1,3,2) a-> () BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,5)(3,6)(4,7) a-> () BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,6)(3,4)(5,7) a-> (2,3,7)(4,6,5) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (1,6)(2,5)(4,7) a-> (1,3,6) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (1,3)(2,5)(4,7) a-> (1,6,3) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,4)(3,7)(5,6) a-> (2,7,6)(3,4,5) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (1,5)(3,6)(4,7) a-> (1,2,5) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,3)(4,6)(5,7) a-> (2,6,7)(3,5,4) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,6)(3,7)(4,5) a-> (2,3,4)(5,7,6) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (1,2)(3,6)(4,7) a-> (1,5,2) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,3)(4,5)(6,7) a-> (2,6,4)(3,5,7) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (1,4)(2,5)(3,6) a-> (1,7,4) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (1,7)(2,5)(3,6) a-> (1,4,7) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,7)(3,5)(4,6) a-> (2,4,3)(5,6,7) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,7)(3,4)(5,6) a-> (2,4,6)(3,7,5) BSRelation-> ()
# x0-> (2,5)(3,6)(4,7) x2-> (2,4)(3,5)(6,7) a-> (2,7,3)(4,5,6) BSRelation-> ()
# x0-> (1,7,3,5)(2,4,6) x2-> (1,7,3,5)(2,4,6) a-> () BSRelation-> ()
# x0-> (1,2,5)(3,6)(4,7) x2-> (1,2,5)(3,6)(4,7) a-> () BSRelation-> ()
# x0-> (1,6)(2,3,4,5,7) x2-> (1,6)(2,3,4,5,7) a-> () BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,5,6,7) a-> () BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,6,5,2) a-> (1,5,2,7,6) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,6,5,3) a-> (1,5,3,7,6) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,6,5,4) a-> (1,5,4,7,6) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (4,5,7,6) a-> (1,7,5,6,4) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (3,5,7,6) a-> (1,7,5,6,3) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,7,2,6) a-> (1,6,7,2,5) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,2,7,5) a-> (1,2,6,5,7) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,7,3,6) a-> (1,6,7,3,5) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,7,4,6) a-> (1,6,7,4,5) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (2,5,7,6) a-> (1,7,5,6,2) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,3,7,5) a-> (1,3,6,5,7) BSRelation-> ()
# x0-> (1,5,6,7) x2-> (1,4,7,5) a-> (1,4,6,5,7) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,4,3,2) a-> () BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,3,4,7) a-> (1,4,7,2,3) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,7,2,4) a-> (1,7,3,4,2) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (2,3,5,4) a-> (1,2,4,3,5) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (2,3,6,4) a-> (1,2,4,3,6) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,3,4,5) a-> (1,4,5,2,3) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,5,2,4) a-> (1,5,3,4,2) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,2,5,3) a-> (1,3,2,5,4) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,3,4,6) a-> (1,4,6,2,3) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,6,2,4) a-> (1,6,3,4,2) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,2,7,3) a-> (1,3,2,7,4) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (2,3,7,4) a-> (1,2,4,3,7) BSRelation-> ()
# x0-> (1,4,3,2) x2-> (1,2,6,3) a-> (1,3,2,6,4) BSRelation-> ()
# x0-> (1,3)(2,7,6,5,4) x2-> (1,3)(2,7,6,5,4) a-> () BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (2,4,6)(3,5,7) a-> () BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,6,3)(2,7,5) a-> (1,4,2,5,6,7,3) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,4,7)(3,6,5) a-> (1,2,6,3,4,5,7) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,5,2)(4,7,6) a-> (1,3,7,4,5,6,2) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,6,5)(2,3,7) a-> (1,4,2,7,6,3,5) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,3,2)(4,5,6) a-> (1,7,5,4,3,6,2) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,2,5)(3,7,4) a-> (1,6,4,7,2,3,5) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,7,4)(2,6,3) a-> (1,5,3,6,7,2,4) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,5,6)(2,7,4) a-> (1,3,7,2,5,4,6) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,5,4)(2,6,7) a-> (1,3,7,6,5,2,4) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,4,5)(3,7,6) a-> (1,2,6,7,4,3,5) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,6,7)(2,5,3) a-> (1,4,2,3,6,5,7) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,7,6)(2,3,4) a-> (1,5,3,2,7,4,6) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,2,3)(4,7,5) a-> (1,6,4,5,2,7,3) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,4,3)(5,6,7) a-> (1,2,6,5,4,7,3) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,3,4)(2,6,5) a-> (1,7,5,6,3,2,4) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,2,7)(3,4,5) a-> (1,6,4,3,2,5,7) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,7,2)(3,6,4) a-> (1,5,3,4,7,6,2) BSRelation-> ()
# x0-> (2,4,6)(3,5,7) x2-> (1,3,6)(2,5,4) a-> (1,7,5,2,3,4,6) BSRelation-> ()
# x0-> (1,7,2,3,4,5,6) x2-> (1,7,2,3,4,5,6) a-> () BSRelation-> ()
# x0-> (1,2,4,6)(3,5,7) x2-> (1,2,4,6)(3,5,7) a-> () BSRelation-> ()
# x0-> (1,6,7) x2-> (1,6,7) a-> () BSRelation-> ()
# x0-> (1,5,4,3,2) x2-> (1,5,4,3,2) a-> () BSRelation-> ()
# x0-> (1,4,2,7,6,5,3) x2-> (1,4,2,7,6,5,3) a-> () BSRelation-> ()
# x0-> (1,3,7,5,2,6,4) x2-> (1,3,7,5,2,6,4) a-> () BSRelation-> ()
# x0-> (2,3,4,5,6,7) x2-> (2,3,4,5,6,7) a-> () BSRelation-> ()
# x0-> (2,3,4,5,6,7) x2-> (2,7,4,3,6,5) a-> (2,6,4)(3,5,7) BSRelation-> ()
# x0-> (2,3,4,5,6,7) x2-> (2,5,4,7,6,3) a-> (2,4,6)(3,7,5) BSRelation-> ()
# x0-> (1,7) x2-> (1,2) a-> (1,2,7) BSRelation-> ()
# x0-> (1,7) x2-> (1,7) a-> () BSRelation-> ()
# x0-> (1,7) x2-> (1,3) a-> (1,3,7) BSRelation-> ()
# x0-> (1,7) x2-> (1,4) a-> (1,4,7) BSRelation-> ()
# x0-> (1,7) x2-> (1,5) a-> (1,5,7) BSRelation-> ()
# x0-> (1,7) x2-> (6,7) a-> (1,7,6) BSRelation-> ()
# x0-> (1,7) x2-> (1,6) a-> (1,6,7) BSRelation-> ()
# x0-> (1,7) x2-> (2,7) a-> (1,7,2) BSRelation-> ()
# x0-> (1,7) x2-> (3,7) a-> (1,7,3) BSRelation-> ()
# x0-> (1,7) x2-> (4,7) a-> (1,7,4) BSRelation-> ()
# x0-> (1,7) x2-> (5,7) a-> (1,7,5) BSRelation-> ()
# x0-> (1,2,3,4,5,6,7) x2-> (1,2,3,4,5,6,7) a-> () BSRelation-> ()
# x0-> (1,6,5,4,3,2) x2-> (1,6,5,4,3,2) a-> () BSRelation-> ()
# x0-> (1,6,5,4,3,2) x2-> (1,2,5,6,3,4) a-> (1,3,5)(2,6,4) BSRelation-> ()
# x0-> (1,6,5,4,3,2) x2-> (1,4,5,2,3,6) a-> (1,5,3)(2,4,6) BSRelation-> ()
# x0-> (1,5,3)(2,7,6,4) x2-> (1,5,3)(2,7,6,4) a-> () BSRelation-> ()
# x0-> (1,4)(2,6,3,7,5) x2-> (1,4)(2,6,3,7,5) a-> () BSRelation-> ()
# x0-> (1,3,6,2,5)(4,7) x2-> (1,3,6,2,5)(4,7) a-> () BSRelation-> ()
# x0-> (3,4) x2-> (3,4) a-> () BSRelation-> ()
# x0-> (3,4) x2-> (1,3) a-> (1,4,3) BSRelation-> ()
# x0-> (3,4) x2-> (2,3) a-> (2,4,3) BSRelation-> ()
# x0-> (3,4) x2-> (4,5) a-> (3,4,5) BSRelation-> ()
# x0-> (3,4) x2-> (3,5) a-> (3,5,4) BSRelation-> ()
# x0-> (3,4) x2-> (1,4) a-> (1,3,4) BSRelation-> ()
# x0-> (3,4) x2-> (2,4) a-> (2,3,4) BSRelation-> ()
# x0-> (3,4) x2-> (3,6) a-> (3,6,4) BSRelation-> ()
# x0-> (3,4) x2-> (4,6) a-> (3,4,6) BSRelation-> ()
# x0-> (3,4) x2-> (3,7) a-> (3,7,4) BSRelation-> ()
# x0-> (3,4) x2-> (4,7) a-> (3,4,7) BSRelation-> ()
# x0-> (1,7,6,5,4,2) x2-> (1,7,6,5,4,2) a-> () BSRelation-> ()
# x0-> (1,7,6,5,4,2) x2-> (1,2,6,7,4,5) a-> (1,4,6)(2,7,5) BSRelation-> ()
# x0-> (1,7,6,5,4,2) x2-> (1,5,6,2,4,7) a-> (1,6,4)(2,5,7) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(3,4) a-> () BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,7)(3,4) a-> (1,7,2) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(4,5) a-> (3,4,5) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,7)(4,5) a-> (1,7,2)(3,4,5) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(3,5) a-> (3,5,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,7)(3,5) a-> (1,7,2)(3,5,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(3,6) a-> (3,6,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,5)(4,7) a-> (1,2,5)(3,4,7) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,7)(3,6) a-> (1,7,2)(3,6,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(4,6) a-> (3,4,6) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,7)(4,6) a-> (1,7,2)(3,4,6) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,5)(3,7) a-> (1,2,5)(3,7,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,5)(3,4) a-> (1,5,2) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,6)(4,7) a-> (1,2,6)(3,4,7) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,5)(4,6) a-> (1,5,2)(3,4,6) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,5)(3,6) a-> (1,5,2)(3,6,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,6)(3,7) a-> (1,2,6)(3,7,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,5)(3,4) a-> (1,2,5) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,6)(3,4) a-> (1,6,2) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,6)(4,5) a-> (1,6,2)(3,4,5) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,6)(3,5) a-> (1,6,2)(3,5,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,5)(4,6) a-> (1,2,5)(3,4,6) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,7)(3,4) a-> (1,2,7) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,6)(3,7) a-> (1,6,2)(3,7,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(3,7) a-> (3,7,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,6)(4,7) a-> (1,6,2)(3,4,7) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,7)(4,5) a-> (1,2,7)(3,4,5) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,7)(3,5) a-> (1,2,7)(3,5,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,2)(4,7) a-> (3,4,7) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,5)(3,6) a-> (1,2,5)(3,6,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,5)(3,7) a-> (1,5,2)(3,7,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (1,5)(4,7) a-> (1,5,2)(3,4,7) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,6)(3,4) a-> (1,2,6) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,7)(3,6) a-> (1,2,7)(3,6,4) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,7)(4,6) a-> (1,2,7)(3,4,6) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,6)(4,5) a-> (1,2,6)(3,4,5) BSRelation-> ()
# x0-> (1,2)(3,4) x2-> (2,6)(3,5) a-> (1,2,6)(3,5,4) BSRelation-> ()
# x0-> (1,6,4)(2,7,5,3) x2-> (1,6,4)(2,7,5,3) a-> () BSRelation-> ()
# x0-> (1,5,2,6,3)(4,7) x2-> (1,5,2,6,3)(4,7) a-> () BSRelation-> ()
# x0-> (1,4,6,2,5)(3,7) x2-> (1,4,6,2,5)(3,7) a-> () BSRelation-> ()
# x0-> (1,3,6)(2,4,5,7) x2-> (1,3,6)(2,4,5,7) a-> () BSRelation-> ()
# x0-> (2,7,6,5,4) x2-> (2,7,6,5,4) a-> () BSRelation-> ()
# x0-> (1,7,5,3,2,6,4) x2-> (1,7,5,3,2,6,4) a-> () BSRelation-> ()
# x0-> (1,2,7,6,5,4) x2-> (1,2,7,6,5,4) a-> () BSRelation-> ()
# x0-> (1,2,7,6,5,4) x2-> (1,4,7,2,5,6) a-> (1,5,7)(2,6,4) BSRelation-> ()
# x0-> (1,2,7,6,5,4) x2-> (1,6,7,4,5,2) a-> (1,7,5)(2,4,6) BSRelation-> ()
# x0-> (1,6,3)(2,5)(4,7) x2-> (1,6,3)(2,5)(4,7) a-> () BSRelation-> ()
# x0-> (1,5)(2,4,6)(3,7) x2-> (1,5)(2,4,6)(3,7) a-> () BSRelation-> ()
# x0-> (1,4,5,7,2,3,6) x2-> (1,4,5,7,2,3,6) a-> () BSRelation-> ()
# x0-> (1,3,5,6,7) x2-> (1,3,5,6,7) a-> () BSRelation-> ()
# x0-> (2,6,4,7,5,3) x2-> (2,6,4,7,5,3) a-> () BSRelation-> ()
# x0-> (2,6,4,7,5,3) x2-> (2,3,4,6,5,7) a-> (2,5,4)(3,6,7) BSRelation-> ()
# x0-> (2,6,4,7,5,3) x2-> (2,7,4,3,5,6) a-> (2,4,5)(3,7,6) BSRelation-> ()
# x0-> (1,7,4,6,3)(2,5) x2-> (1,7,4,6,3)(2,5) a-> () BSRelation-> ()
# x0-> (1,2,6,4,7,5,3) x2-> (1,2,6,4,7,5,3) a-> () BSRelation-> ()
# x0-> (1,6,2,4,5)(3,7) x2-> (1,6,2,4,5)(3,7) a-> () BSRelation-> ()
# x0-> (1,5,7,2,3,6) x2-> (1,5,7,2,3,6) a-> () BSRelation-> ()
# x0-> (1,5,7,2,3,6) x2-> (1,2,7,6,3,5) a-> (1,7,3)(2,5,6) BSRelation-> ()
# x0-> (1,5,7,2,3,6) x2-> (1,6,7,5,3,2) a-> (1,3,7)(2,6,5) BSRelation-> ()
# x0-> (1,4,3,5,6,7) x2-> (1,4,3,5,6,7) a-> () BSRelation-> ()
# x0-> (1,4,3,5,6,7) x2-> (1,5,3,7,6,4) a-> (1,3,6)(4,7,5) BSRelation-> ()
# x0-> (1,4,3,5,6,7) x2-> (1,7,3,4,6,5) a-> (1,6,3)(4,5,7) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,3,4,2) a-> () BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,4,3,7) a-> (1,3,7,2,4) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,7,2,3) a-> (1,7,4,3,2) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (2,4,7,3) a-> (1,2,3,4,7) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,4,3,5) a-> (1,3,5,2,4) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,5,2,3) a-> (1,5,4,3,2) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (2,4,5,3) a-> (1,2,3,4,5) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,2,5,4) a-> (1,4,2,5,3) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,4,3,6) a-> (1,3,6,2,4) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,6,2,3) a-> (1,6,4,3,2) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (2,4,6,3) a-> (1,2,3,4,6) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,2,7,4) a-> (1,4,2,7,3) BSRelation-> ()
# x0-> (1,3,4,2) x2-> (1,2,6,4) a-> (1,4,2,6,3) BSRelation-> ()
# x0-> (2,5)(3,7,4,6) x2-> (2,5)(3,7,4,6) a-> () BSRelation-> ()
# x0-> (2,5)(3,7,4,6) x2-> (1,6,7,3)(2,5) a-> (1,4,7,6,3) BSRelation-> ()
# x0-> (2,5)(3,7,4,6) x2-> (1,3,4,7)(2,5) a-> (1,6,4,3,7) BSRelation-> ()
# x0-> (2,5)(3,7,4,6) x2-> (1,5)(3,7,4,6) a-> (1,2,5) BSRelation-> ()
# x0-> (2,5)(3,7,4,6) x2-> (1,2)(3,7,4,6) a-> (1,5,2) BSRelation-> ()
# x0-> (2,5)(3,7,4,6) x2-> (1,7,6,4)(2,5) a-> (1,3,6,7,4) BSRelation-> ()
# x0-> (2,5)(3,7,4,6) x2-> (1,4,3,6)(2,5) a-> (1,7,3,4,6) BSRelation-> ()
# x0-> (1,7,3,6,2,4,5) x2-> (1,7,3,6,2,4,5) a-> () BSRelation-> ()
# x0-> (1,2,5)(3,7,4,6) x2-> (1,2,5)(3,7,4,6) a-> () BSRelation-> ()
# x0-> (1,6)(2,3,5,7) x2-> (1,6)(2,3,5,7) a-> () BSRelation-> ()
# x0-> (1,6)(2,3,5,7) x2-> (1,6)(2,4,7,3) a-> (2,4,5,3,7) BSRelation-> ()
# x0-> (1,6)(2,3,5,7) x2-> (2,3,5,7)(4,6) a-> (1,6,4) BSRelation-> ()
# x0-> (1,6)(2,3,5,7) x2-> (1,4)(2,3,5,7) a-> (1,4,6) BSRelation-> ()
# x0-> (1,6)(2,3,5,7) x2-> (1,6)(2,7,4,5) a-> (2,5,7,4,3) BSRelation-> ()
# x0-> (1,6)(2,3,5,7) x2-> (1,6)(3,7,5,4) a-> (2,7,3,5,4) BSRelation-> ()
# x0-> (1,6)(2,3,5,7) x2-> (1,6)(2,5,3,4) a-> (2,3,4,7,5) BSRelation-> ()
# x0-> (1,5,6,7)(3,4) x2-> (1,5,6,7)(3,4) a-> () BSRelation-> ()
# x0-> (1,5,6,7)(3,4) x2-> (1,5,6,7)(2,3) a-> (2,4,3) BSRelation-> ()
# x0-> (1,5,6,7)(3,4) x2-> (1,6,5,2)(3,4) a-> (1,5,2,7,6) BSRelation-> ()
# x0-> (1,5,6,7)(3,4) x2-> (1,5,6,7)(2,4) a-> (2,3,4) BSRelation-> ()
# x0-> (1,5,6,7)(3,4) x2-> (1,7,2,6)(3,4) a-> (1,6,7,2,5) BSRelation-> ()
# x0-> (1,5,6,7)(3,4) x2-> (1,2,7,5)(3,4) a-> (1,2,6,5,7) BSRelation-> ()
# x0-> (1,5,6,7)(3,4) x2-> (2,5,7,6)(3,4) a-> (1,7,5,6,2) BSRelation-> ()
# x0-> (1,4,2) x2-> (1,4,2) a-> () BSRelation-> ()
# x0-> (1,3,2,7,6,5,4) x2-> (1,3,2,7,6,5,4) a-> () BSRelation-> ()
# x0-> (2,4,5,7,3,6) x2-> (2,4,5,7,3,6) a-> () BSRelation-> ()
# x0-> (2,4,5,7,3,6) x2-> (2,7,5,6,3,4) a-> (2,5,3)(4,6,7) BSRelation-> ()
# x0-> (2,4,5,7,3,6) x2-> (2,6,5,4,3,7) a-> (2,3,5)(4,7,6) BSRelation-> ()
# x0-> (1,7,2,3,5,6) x2-> (1,7,2,3,5,6) a-> () BSRelation-> ()
# x0-> (1,7,2,3,5,6) x2-> (1,6,2,7,5,3) a-> (1,5,2)(3,6,7) BSRelation-> ()
# x0-> (1,7,2,3,5,6) x2-> (1,3,2,6,5,7) a-> (1,2,5)(3,7,6) BSRelation-> ()
# x0-> (1,2,4,5,7,3,6) x2-> (1,2,4,5,7,3,6) a-> () BSRelation-> ()
# x0-> (1,6,7)(3,4) x2-> (1,6,7)(3,4) a-> () BSRelation-> ()
# x0-> (1,6,7)(3,4) x2-> (1,6,7)(2,3) a-> (2,4,3) BSRelation-> ()
# x0-> (1,6,7)(3,4) x2-> (1,6,7)(4,5) a-> (3,4,5) BSRelation-> ()
# x0-> (1,6,7)(3,4) x2-> (1,6,7)(3,5) a-> (3,5,4) BSRelation-> ()
# x0-> (1,6,7)(3,4) x2-> (1,6,7)(2,4) a-> (2,3,4) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,5,4,2) a-> () BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,4,5,3) a-> (1,5,3,2,4) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,2,3,4) a-> (1,4,2,3,5) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,4,5,7) a-> (1,5,7,2,4) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,7,2,5) a-> (1,7,4,5,2) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (2,4,6,5) a-> (1,2,5,4,6) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (2,4,3,5) a-> (1,2,5,4,3) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,3,2,5) a-> (1,3,4,5,2) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,4,5,6) a-> (1,5,6,2,4) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,2,7,4) a-> (1,4,2,7,5) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,6,2,5) a-> (1,6,4,5,2) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (1,2,6,4) a-> (1,4,2,6,5) BSRelation-> ()
# x0-> (1,5,4,2) x2-> (2,4,7,5) a-> (1,2,5,4,7) BSRelation-> ()
# x0-> (1,4)(2,7,6,5,3) x2-> (1,4)(2,7,6,5,3) a-> () BSRelation-> ()
# x0-> (1,3)(2,6,4,7,5) x2-> (1,3)(2,6,4,7,5) a-> () BSRelation-> ()
# x0-> (2,3,5,6,7) x2-> (2,3,5,6,7) a-> () BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,2)(3,4) a-> (1,2,7) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,7)(3,4) a-> () BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,7)(2,3) a-> (2,4,3) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,2)(4,5) a-> (1,2,7)(3,4,5) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,7)(4,5) a-> (3,4,5) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,2)(3,5) a-> (1,2,7)(3,5,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,7)(3,5) a-> (3,5,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,7)(2,4) a-> (2,3,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,2)(3,6) a-> (1,2,7)(3,6,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,7)(3,6) a-> (3,6,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,2)(4,6) a-> (1,2,7)(3,4,6) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,7)(4,6) a-> (3,4,6) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,5)(3,4) a-> (1,5,7) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,5)(2,3) a-> (1,5,7)(2,4,3) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,5)(4,6) a-> (1,5,7)(3,4,6) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,5)(3,6) a-> (1,5,7)(3,6,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (3,6)(5,7) a-> (1,7,5)(3,6,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (4,6)(5,7) a-> (1,7,5)(3,4,6) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,5)(2,4) a-> (1,5,7)(2,3,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (3,4)(6,7) a-> (1,7,6) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,6)(3,4) a-> (1,6,7) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,6)(2,3) a-> (1,6,7)(2,4,3) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,3)(6,7) a-> (1,7,6)(2,4,3) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (4,5)(6,7) a-> (1,7,6)(3,4,5) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,6)(4,5) a-> (1,6,7)(3,4,5) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (3,5)(6,7) a-> (1,7,6)(3,5,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,6)(3,5) a-> (1,6,7)(3,5,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (1,6)(2,4) a-> (1,6,7)(2,3,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,4)(6,7) a-> (1,7,6)(2,3,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,7)(3,4) a-> (1,7,2) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,7)(4,5) a-> (1,7,2)(3,4,5) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,7)(3,5) a-> (1,7,2)(3,5,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (3,4)(5,7) a-> (1,7,5) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,3)(5,7) a-> (1,7,5)(2,4,3) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,7)(3,6) a-> (1,7,2)(3,6,4) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,7)(4,6) a-> (1,7,2)(3,4,6) BSRelation-> ()
# x0-> (1,7)(3,4) x2-> (2,4)(5,7) a-> (1,7,5)(2,3,4) BSRelation-> ()
# x0-> (1,2,3,5,6,7) x2-> (1,2,3,5,6,7) a-> () BSRelation-> ()
# x0-> (1,2,3,5,6,7) x2-> (1,5,3,7,6,2) a-> (1,3,6)(2,7,5) BSRelation-> ()
# x0-> (1,2,3,5,6,7) x2-> (1,7,3,2,6,5) a-> (1,6,3)(2,5,7) BSRelation-> ()
# x0-> (1,6,5,4,2) x2-> (1,6,5,4,2) a-> () BSRelation-> ()
# x0-> (1,5,3,2,7,6,4) x2-> (1,5,3,2,7,6,4) a-> () BSRelation-> ()
# x0-> (1,4,7,5,2,6,3) x2-> (1,4,7,5,2,6,3) a-> () BSRelation-> ()
# x0-> (1,3,7,4,6,2,5) x2-> (1,3,7,4,6,2,5) a-> () BSRelation-> ()
# x0-> (3,5,4) x2-> (3,5,4) a-> () BSRelation-> ()
# x0-> (1,7,6,5,3,4,2) x2-> (1,7,6,5,3,4,2) a-> () BSRelation-> ()
# x0-> (1,2)(3,5,4) x2-> (1,2)(3,5,4) a-> () BSRelation-> ()
# x0-> (1,2)(3,5,4) x2-> (1,7)(3,5,4) a-> (1,7,2) BSRelation-> ()
# x0-> (1,2)(3,5,4) x2-> (1,6)(3,5,4) a-> (1,6,2) BSRelation-> ()
# x0-> (1,2)(3,5,4) x2-> (2,7)(3,5,4) a-> (1,2,7) BSRelation-> ()
# x0-> (1,2)(3,5,4) x2-> (2,6)(3,5,4) a-> (1,2,6) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,6,4)(2,7,5) a-> () BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,3,7)(4,6,5) a-> (1,3,2,5,6,7,4) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,7,3)(2,5,6) a-> (1,2,7,3,4,6,5) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,4,2)(3,5,6) a-> (1,6,3,7,2,4,5) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,2,5)(3,4,7) a-> (1,5,4,2,7,3,6) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,5,7)(2,3,4) a-> (1,7,4,5,2,3,6) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,2,3)(5,7,6) a-> (1,5,2,3,4,6,7) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (2,5,4)(3,6,7) a-> (1,4,5,6,2,7,3) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (2,4,7)(3,6,5) a-> (1,4,2,6,7,5,3) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,4,5)(3,7,6) a-> (1,6,3,2,5,4,7) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,5,3)(2,6,7) a-> (1,7,5,3,4,6,2) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,7,6)(2,4,3) a-> (1,2,6,4,3,5,7) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,3,5)(2,4,6) a-> (1,3,7,2,6,5,4) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,5,6)(3,7,4) a-> (1,7,6,4,3,2,5) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (2,3,6)(4,5,7) a-> (1,4,7,6,5,2,3) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,3,2)(4,6,7) a-> (1,3,5,7,6,2,4) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,7,2)(3,4,5) a-> (1,2,4,7,5,3,6) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,4,7)(2,6,3) a-> (1,6,3,5,7,4,2) BSRelation-> ()
# x0-> (1,6,4)(2,7,5) x2-> (1,2,6)(3,5,4) a-> (1,5,6,4,3,7,2) BSRelation-> ()
# x0-> (1,5)(2,6,3)(4,7) x2-> (1,5)(2,6,3)(4,7) a-> () BSRelation-> ()
# x0-> (1,4,6,2,5,7,3) x2-> (1,4,6,2,5,7,3) a-> () BSRelation-> ()
# x0-> (1,3,7,2,4,5,6) x2-> (1,3,7,2,4,5,6) a-> () BSRelation-> ()
# x0-> (2,7,6,5,3,4) x2-> (2,7,6,5,3,4) a-> () BSRelation-> ()
# x0-> (2,7,6,5,3,4) x2-> (2,4,6,7,3,5) a-> (2,3,6)(4,7,5) BSRelation-> ()
# x0-> (2,7,6,5,3,4) x2-> (2,5,6,4,3,7) a-> (2,6,3)(4,5,7) BSRelation-> ()
# x0-> (1,7,5,2,6,4) x2-> (1,7,5,2,6,4) a-> () BSRelation-> ()
# x0-> (1,7,5,2,6,4) x2-> (1,2,5,4,6,7) a-> (1,5,6)(2,7,4) BSRelation-> ()
# x0-> (1,7,5,2,6,4) x2-> (1,4,5,7,6,2) a-> (1,6,5)(2,4,7) BSRelation-> ()
# x0-> (1,2,7,6,5,3,4) x2-> (1,2,7,6,5,3,4) a-> () BSRelation-> ()
# x0-> (1,6,3,2,5)(4,7) x2-> (1,6,3,2,5)(4,7) a-> () BSRelation-> ()
# x0-> (1,5,7,3)(2,4,6) x2-> (1,5,7,3)(2,4,6) a-> () BSRelation-> ()
# x0-> (1,4,5,6)(2,3,7) x2-> (1,4,5,6)(2,3,7) a-> () BSRelation-> ()
# x0-> (1,3,6,7) x2-> (1,3,6,7) a-> () BSRelation-> ()
# x0-> (1,3,6,7) x2-> (3,7,6,5) a-> (1,7,3,6,5) BSRelation-> ()
# x0-> (1,3,6,7) x2-> (3,7,6,4) a-> (1,7,3,6,4) BSRelation-> ()
# x0-> (1,3,6,7) x2-> (1,6,3,2) a-> (1,3,2,7,6) BSRelation-> ()
# x0-> (1,3,6,7) x2-> (1,6,3,4) a-> (1,3,4,7,6) BSRelation-> ()
# x0-> (1,3,6,7) x2-> (1,6,3,5) a-> (1,3,5,7,6) BSRelation-> ()
# x0-> (1,3,6,7) x2-> (1,7,2,6) a-> (1,6,7,2,3) BSRelation-> ()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f6299c84207e> in <module>
# ----> 1 find_BS_homs(Integer(7))
#
# <ipython-input-10-02274b1a8b4e> in find_BS_homs(p)
#       9         for g_2 in S_p:
#      10             pair=[g_1,g_2]
# ---> 11             hom_p=BSF.hom([S_p(g) for g in pair])
#      12             if hom_p.image(BSRelation)==S_p.identity():
#      13                 good_homs_p.append(hom_p)
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.hom (build/cythonized/sage/structure/parent.c:12200)()
#    1421             kwds['base_map'] = base_map
#    1422         Hom_kwds = {} if category is None else {'category': category}
# -> 1423         return self.Hom(codomain, **Hom_kwds)(im_gens, **kwds)
#    1424
#    1425     #################################################################################
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9338)()
#     896         if mor is not None:
#     897             if no_extra_args:
# --> 898                 return mor._call_(x)
#     899             else:
#     900                 return mor._call_with_args(x, args, kwds)
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4514)()
#     154         cdef Parent C = self._codomain
#     155         try:
# --> 156             return C._element_constructor(x)
#     157         except Exception:
#     158             if print_warnings:
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/groups/libgap_morphism.py in _element_constructor_(self, x, check, **options)
#     692                 ByImagesNC = libgap.function_factory("GroupHomomorphismByImagesNC")
#     693                 phi = ByImagesNC(dom.gap(), codom.gap(), gens, imgs)
# --> 694             return self.element_class(self, phi, check=check, **options)
#     695         if isinstance(x, GapElement):
#     696             try:
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/groups/libgap_morphism.py in __init__(self, homset, gap_hom, check)
#     254          to General Linear Group of degree 3 over Integer Ring in Category of groups
#     255     """
# --> 256     def __init__(self, homset, gap_hom, check=True):
#     257         r"""
#     258         Constructor method.
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
#find_BS_homs(11)#didn't find any after 2 hours
# Out:
# x0-> () x2-> () a-> () BSRelation-> ()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f23a0a0d882a> in <module>
# ----> 1 find_BS_homs(Integer(11))
#
# <ipython-input-10-02274b1a8b4e> in find_BS_homs(p)
#       9         for g_2 in S_p:
#      10             pair=[g_1,g_2]
# ---> 11             hom_p=BSF.hom([S_p(g) for g in pair])
#      12             if hom_p.image(BSRelation)==S_p.identity():
#      13                 good_homs_p.append(hom_p)
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.hom (build/cythonized/sage/structure/parent.c:12200)()
#    1421             kwds['base_map'] = base_map
#    1422         Hom_kwds = {} if category is None else {'category': category}
# -> 1423         return self.Hom(codomain, **Hom_kwds)(im_gens, **kwds)
#    1424
#    1425     #################################################################################
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9338)()
#     896         if mor is not None:
#     897             if no_extra_args:
# --> 898                 return mor._call_(x)
#     899             else:
#     900                 return mor._call_with_args(x, args, kwds)
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4514)()
#     154         cdef Parent C = self._codomain
#     155         try:
# --> 156             return C._element_constructor(x)
#     157         except Exception:
#     158             if print_warnings:
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/groups/libgap_morphism.py in _element_constructor_(self, x, check, **options)
#     684                 if not len(gens) == len(imgs):
#     685                     raise ValueError("provide an image for each generator")
# --> 686                 phi = libgap.GroupHomomorphismByImages(dom.gap(), codom.gap(), gens, imgs)
#     687                 # if it is not a group homomorphism, then
#     688                 # self._phi is the gap boolean fail
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/libs/gap/element.pyx in sage.libs.gap.element.GapElement_Function.__call__ (build/cythonized/sage/libs/gap/element.c:20393)()
#    2568             # We called a procedure that does not return anything
#    2569             return None
# -> 2570         return make_any_gap_element(self.parent(), result)
#    2571
#    2572
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/libs/gap/element.pyx in sage.libs.gap.element.make_any_gap_element (build/cythonized/sage/libs/gap/element.c:6265)()
#     352                 return make_GapElement_IntegerMod(parent, obj)
#     353         if num == T_COMOBJ:
# --> 354             if result.IsRing():
#     355                 return make_GapElement_Ring(parent, obj)
#     356         return result
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/libs/gap/element.pyx in sage.libs.gap.element.GapElement.__getattr__ (build/cythonized/sage/libs/gap/element.c:8321)()
#     734         try:
#     735             proxy = make_GapElement_MethodProxy\
# --> 736                 (self.parent(), gap_eval(name), self)
#     737         except GAPError:
#     738             raise AttributeError(f"'{name}' is not defined in GAP")
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/libs/gap/util.pyx in sage.libs.gap.util.gap_eval (build/cythonized/sage/libs/gap/util.c:6044)()
#     394     # its contents.
#     395     cmd = str_to_bytes(gap_string + ';\n')
# --> 396     sig_on()
#     397     try:
#     398         GAP_Enter()
#
# KeyboardInterrupt:
